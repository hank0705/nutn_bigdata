# %% [markdown]
# <a href="https://colab.research.google.com/github/hank0705/nutn_bigdata/blob/main/0420%E6%9C%9F%E4%B8%AD%E8%80%83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("SportsAnalytics")

library(SportsAnalytics)
NBA1617<-fetch_NBAPlayerStatistics("16-17")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
NBA1617Order<-NBA1617[order(NBA1617$GamesPlayed,decreasing = T),]
NBA1617Order[1:20,]
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 57  NBA    Corey Brewer     LAL  SF       82          1281
# 80  NBA    Marquese Chriss  PHO  PF       82          1740
# 84  NBA    Jordan Clarkson  LAL  PG       82          2397
# 94  NBA    Jamal Crawford   LAC  SG       82          2158
# 112 NBA    Gorgui Dieng     MIN  C        82          2655
# 160 NBA    Marcin Gortat    WAS  C        82          2561
# 181 NBA    Tobias Harris    DET  SF       82          2566
# 193 NBA    Buddy Hield      SAC  SG       82          1882
# 200 NBA    Justin Holiday   NYK  SG       82          1633
# 213 NBA    Ersan Ilyasova   ATL  PF       82          2141
# 214 NBA    Joe Ingles       UTA  SF       82          1974
# 319 NBA    Jamal Murray     DEN  SG       82          1763
# 355 NBA    Elfrid Payton    ORL  PG       82          2412
# 412 NBA    Marrees Speights LAC  C        82          1285
# 423 NBA    Jeff Teague      IND  PG       82          2658
# ...

# %%
subset(NBA1617,Team=="LAL")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 20  NBA    Ron Artest       LAL  PF       25           162
# 49  NBA    Tarik Black      LAL  C        67          1090
# 57  NBA    Corey Brewer     LAL  SF       82          1281
# 84  NBA    Jordan Clarkson  LAL  PG       82          2397
# 108 NBA    Luol Deng        LAL  SF       56          1482
# 127 NBA    Tyler Ennis      LAL  PG       53           587
# 207 NBA    Marcelo Huertas  LAL  PG       23           236
# 215 NBA    Brandon Ingram   LAL  SF       79          2277
# 315 NBA    Timofey Mozgov   LAL  C        54          1104
# 321 NBA    Larry Nance      LAL  PF       63          1438
# 335 NBA    David Nwaba      LAL  PG       20           398
# 372 NBA    Julius Randle    LAL  PF       74          2131
# 382 NBA    Thomas Robinson  LAL  PF       47           559
# 391 NBA    D'angelo Russell LAL  PG       63          1813
# 481 NBA    Nick Young       LAL  SF       60          1555
# ...

# %%
NBA1617[grepl("James",NBA1617$Name),]
# Out:
#     League Name          Team Position GamesPlayed TotalMinutesPlayed
# 126 NBA    James Ennis   MEM  SF       64          1502
# 173 NBA    James Harden  HOU  SG       81          2954
# 221 NBA    Lebron James  CLE  SF       74          2793
# 229 NBA    James Johnson MIA  PF       76          2086
# 238 NBA    James Jones   CLE  SG       47           379
# 286 NBA    James Mcadoo  GSW  PF       51           458
# 479 NBA    James Young   BOS  SG       29           221
#     FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 126 146             322                 51        137             ⋯  46
# 173 674            1532                262        756             ⋯ 122
# 221 736            1344                124        342             ⋯  92
# 229 368             768                 87        255             ⋯  75
# 238  44              92                 31         66             ⋯   7
# 286  62             118                  2          8             ⋯  18
# ...

# %%
install.packages("ggplot2")

library(ggplot2)
NBA1617<-fetch_NBAPlayerStatistics("16-17")
qplot(FieldGoalsAttempted, TotalPoints, data = NBA1617)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# plot without title

# %%
qplot(TotalPoints, data = NBA1617, fill = Position)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data = NBA1617, facets = Position~ .)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data = NBA1617, facets = .~ Position )
# Out:
# plot without title
